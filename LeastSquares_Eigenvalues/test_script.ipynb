# %%
# %run lstsq_eigs.py
least_squares(np.array([[1,1],[1,1],[1,0]]),
              np.array([3, 2, 0]))
# Out:
# array([-4.8639261e-17,  2.5000000e+00])

# %%
# %run lstsq_eigs.py
line_fit()

# %%
# %run lstsq_eigs.py
polynomial_fit()
