# %%
# %run matplotlib_intro.py
var_of_means(2000)
# Out:
# np.float64(0.0005401203102467209)

# %%
# %run matplotlib_intro.py
prob1()

# %%
# %run matplotlib_intro.py
prob2()

# %%
# %run matplotlib_intro.py
prob3()

# %%
# %run matplotlib_intro.py
prob4()

# %%
# %run matplotlib_intro.py
prob5()

# %%
# %run matplotlib_intro.py
prob6()
